# %% [markdown]
# # Integration of Colab with VS Code
#
# References:
# [1]: https://www.freecodecamp.org/news/how-to-use-google-colab-with-vs-code/

# %%
from IPython.display import clear_output

# %%
 # !pip install colabcode
 clear_output()

# %%
from colabcode import ColabCode

# %%
ColabCode(port=10000, mount_drive =True)
# Out:
# ERROR:pyngrok.process.ngrok:t=2024-04-07T14:45:03+0000 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="authentication failed: Usage of ngrok requires a verified account and authtoken.\n\nSign up for an account: https://dashboard.ngrok.com/signup\nInstall your authtoken: https://dashboard.ngrok.com/get-started/your-authtoken\r\n\r\nERR_NGROK_4018\r\n"
# ERROR:pyngrok.process.ngrok:t=2024-04-07T14:45:03+0000 lvl=eror msg="session closing" obj=tunnels.session err="authentication failed: Usage of ngrok requires a verified account and authtoken.\n\nSign up for an account: https://dashboard.ngrok.com/signup\nInstall your authtoken: https://dashboard.ngrok.com/get-started/your-authtoken\r\n\r\nERR_NGROK_4018\r\n"
# ---------------------------------------------------------------------------
# PyngrokNgrokError                         Traceback (most recent call last)
# <ipython-input-5-ea72613e3a14> in <cell line: 1>()
# ----> 1 ColabCode(port=10000, mount_drive =True)
#
# ...
