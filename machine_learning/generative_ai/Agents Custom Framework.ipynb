# %% [markdown]
# # Imnplementing a custom framework for Agent Building
#
# Reference:
# * https://github.com/anthropics/anthropic-cookbook/tree/main/patterns/agents

# %%
# %pip install -q huggingface-hub==0.23.2
# %pip install -q transformers==4.47.0
# %pip install -q datasets==2.19.1
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 401.7/401.7 kB 5.6 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# peft 0.14.0 requires huggingface-hub>=0.25.0, but you have huggingface-hub 0.23.2 which is incompatible.
# transformers 4.47.1 requires huggingface-hub<1.0,>=0.24.0, but you have huggingface-hub 0.23.2 which is incompatible.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.5/43.5 kB 1.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 27.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 450.5/450.5 kB 2.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.0/542.0 kB 9.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 7.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.0/172.0 kB 10.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 9.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 11.8 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.3.1 which is incompatible.

# %% [markdown]
# ## 0. Common functions

# %%
import os
import re
from huggingface_hub import InferenceClient

# %%
def llm_call(
    prompt: str,
    system_prompt: str = "",
    # model="Qwen/Qwen2.5-72B-Instruct",
    model="microsoft/Phi-3.5-mini-instruct",
    # model = "Qwen/QwQ-32B-Preview",
    # model = "Qwen/Qwen2.5-Coder-32B-Instruct",
    # model = "mistralai/Mistral-Nemo-Instruct-2407"
    ) -> str:
    """
    Calls the model with the given prompt and returns the response.

    NOTE: Uses HF Inference API

    Args:
        prompt (str): The user prompt to send to the model.
        system_prompt (str, optional): The system prompt to send to the model. Defaults to "".
        model (str, optional): The model to use for the call. Defaults to "claude-3-5-sonnet-20241022".

    Returns:
        str: The response from the language model.
    """
    dct_params={'max_new_tokens': 1000, 'temperature': 0.1, 'return_full_text': False}
    client = InferenceClient()
    input_prompt = system_prompt + '\n\n' + prompt
    response = client.text_generation(
        input_prompt,
        model=model,
        **dct_params
        )
    return response

# %%
def extract_xml(text: str, tag: str) -> str:
    """
    Extracts the content of the specified XML tag from the given text. Used for parsing structured responses

    Args:
        text (str): The text containing the XML.
        tag (str): The XML tag to extract content from.

    Returns:
        str: The content of the specified XML tag, or an empty string if the tag is not found.
    """
    match = re.search(f'<{tag}>(.*?)</{tag}>', text, re.DOTALL)
    return match.group(1) if match else ""

# %% [markdown]
# ### 0.1. Specific functions

# %%
import time
from concurrent.futures import ThreadPoolExecutor
from typing import List, Dict, Callable

# %%
def chain(input: str, prompts: List[str], debug_mode=True) -> str:
    """Chain multiple LLM calls sequentially, passing results between steps."""
    result = input
    for i, prompt in enumerate(prompts, 1):
        print(f"\nStep {i}:")
        result = llm_call(f"{prompt}\nInput: {result}")
        print(result)

        if debug_mode:
          time.sleep(10)
    return result

# %%
def parallel(prompt: str, inputs: List[str], n_workers: int = 3) -> List[str]:
    """Process multiple inputs concurrently with the same prompt."""
    with ThreadPoolExecutor(max_workers=n_workers) as executor:
        futures = [executor.submit(llm_call, f"{prompt}\nInput: {x}") for x in inputs]
        return [f.result() for f in futures]

# %%
def route(input: str, routes: Dict[str, str]) -> str:
    """Route input to specialized prompt using content classification."""
    # First determine appropriate route using LLM with chain-of-thought
    print(f"\nAvailable routes: {list(routes.keys())}")
    selector_prompt = f"""
    Analyze the input and select the most appropriate support team from these options: {list(routes.keys())}
    First explain your reasoning, then provide your selection in this XML format:

    <reasoning>
    Brief explanation of why this ticket should be routed to a specific team.
    Consider key terms, user intent, and urgency level.
    </reasoning>

    <selection>
    The chosen team name
    </selection>

    Input: {input}""".strip()

    route_response = llm_call(selector_prompt)
    reasoning = extract_xml(route_response, 'reasoning')
    route_key = extract_xml(route_response, 'selection').strip().lower()

    print("Routing Analysis:")
    print(reasoning)
    print(f"\nSelected route: {route_key}")

    # Process input with selected specialized prompt
    selected_prompt = routes[route_key]
    return llm_call(f"{selected_prompt}\nInput: {input}")

# %%
def generate(prompt: str, task: str, context: str = "") -> tuple[str, str]:
    """Generate and improve a solution based on feedback."""
    full_prompt = f"{prompt}\n{context}\nTask: {task}" if context else f"{prompt}\nTask: {task}"
    print("\n=== INPUT START ===")
    print(f"Full prompt:\n{full_prompt}\n")
    print("\n=== INPUT END ===")

    response = llm_call(full_prompt)
    thoughts = extract_xml(response, "thoughts")
    result = extract_xml(response, "response")

    print("\n=== GENERATION START ===")
    print(f"Thoughts:\n{thoughts}\n")
    print(f"Generated:\n{result}")
    print("=== GENERATION END ===\n")

    return thoughts, result

def evaluate(prompt: str, content: str, task: str) -> tuple[str, str]:
    """Evaluate if a solution meets requirements."""
    full_prompt = f"{prompt}\nOriginal task: {task}\nContent to evaluate: {content}"
    response = llm_call(full_prompt)
    evaluation = extract_xml(response, "evaluation")
    feedback = extract_xml(response, "feedback")

    print("=== EVALUATION START ===")
    print(f"Status: {evaluation}")
    print(f"Feedback: {feedback}")
    print("=== EVALUATION END ===\n")

    return evaluation, feedback

def loop(task: str, evaluator_prompt: str, generator_prompt: str, n_max_iter = 5, debug_mode = True) -> tuple[str, list[dict]]:
    """Keep generating and evaluating until requirements are met."""
    memory = []
    chain_of_thought = []

    thoughts, result = generate(generator_prompt, task)
    memory.append(result)
    chain_of_thought.append({"thoughts": thoughts, "result": result})

    i = 0
    while True:
        # =======================
        if debug_mode:
          time.sleep(20)
        # =======================

        evaluation, feedback = evaluate(evaluator_prompt, result, task)
        if evaluation == "PASS" or i <= n_max_iter:
            return result, chain_of_thought

        context = "\n".join([
            "Previous attempts:",
            *[f"- {m}" for m in memory],
            f"\nFeedback: {feedback}"
        ])

        # =======================
        if debug_mode:
          time.sleep(20)
        # =======================

        thoughts, result = generate(generator_prompt, task, context)
        memory.append(result)
        chain_of_thought.append({"thoughts": thoughts, "result": result})

        i += 1

# %% [markdown]
# ## 1. Workflow examples

# %% [markdown]
# ### 1.1. Prompt chaining
# * Prompt-Chaining: Decomposes a task into sequential subtasks, where each step builds on previous results

# %%
# Example 1: Chain workflow for structured data extraction and formatting
# Each step progressively transforms raw text into a formatted table

data_processing_steps = [
    """Extract only the numerical values and their associated metrics from the text.
    Format each as 'value: metric' on a new line.
    Example format:
    92: customer satisfaction
    45%: revenue growth""",

    """Convert all numerical values to percentages where possible.
    If not a percentage or points, convert to decimal (e.g., 92 points -> 92%).
    Keep one number per line.
    Example format:
    92%: customer satisfaction
    45%: revenue growth""",

    """Sort all lines in descending order by numerical value.
    Keep the format 'value: metric' on each line.
    Example:
    92%: customer satisfaction
    87%: employee satisfaction""",

    """Format the sorted data as a markdown table with columns:
    | Metric | Value |
    |:--|--:|
    | Customer Satisfaction | 92% |"""
]

report = """
Q3 Performance Summary:
Our customer satisfaction score rose to 92 points this quarter.
Revenue grew by 45% compared to last year.
Market share is now at 23% in our primary market.
Customer churn decreased to 5% from 8%.
New user acquisition cost is $43 per user.
Product adoption rate increased to 78%.
Employee satisfaction is at 87 points.
Operating margin improved to 34%.
"""

print("\nInput text:")
print(report)
formatted_result = chain(report, data_processing_steps)
print(formatted_result)
# Out:
# Input text:
#
# Q3 Performance Summary:
# Our customer satisfaction score rose to 92 points this quarter.
# Revenue grew by 45% compared to last year.
# Market share is now at 23% in our primary market.
# Customer churn decreased to 5% from 8%.
# New user acquisition cost is $43 per user.
# Product adoption rate increased to 78%.
# Employee satisfaction is at 87 points.
# Operating margin improved to 34%.
#
#
# Step 1:
#
# Output:
# 92: customer satisfaction
# 45%: revenue growth
# 23%: market share
# 5%: customer churn
# $43: new user acquisition cost
# 78%: product adoption rate
# 87: employee satisfaction
# 34%: operating margin
#
#
#
# Step 2:
# Output:
# 92: customer satisfaction
# 45: revenue growth
# 23: market share
# 5: customer churn
# 43: new user acquisition cost
# 78: product adoption rate
# 87: employee satisfaction
# 34: operating margin
#
# Note: The dollar sign ($) has been left as is since it's not a percentage or a point value and cannot be converted to a decimal. If the instruction was to convert all values to a decimal format, the dollar sign would be removed, and the value would be converted to a decimal (e.g., $43 would become 43.00). However, as per the given instruction, the output remains as is.
#
# Step 3:
#
#
# Step 4:
#
#
# | Metric | Value |
# |:--|--:|
# | Customer Satisfaction | 92% |
# | Employee Turnover Rate | 15% |
# | Net Profit Margin | 22% |
# | Revenue Growth | 18% |
#
# Sorted Data:
#
# | Metric | Value |
# |:--|--:|
# | Customer Satisfaction | 92% |
# | Revenue Growth | 18% |
# | Net Profit Margin | 22% |
# | Employee Turnover Rate | 15% |
#
# Note: The sorted data is based on the numerical values in ascending order. The "Customer Satisfaction" metric has the highest value, followed by "Revenue Growth", "Net Profit Margin", and "Employee Turnover Rate".
#
#
# | Metric | Value |
# |:--|--:|
# | Customer Satisfaction | 92% |
# | Employee Turnover Rate | 15% |
# | Net Profit Margin | 22% |
# | Revenue Growth | 18% |
#
# Sorted Data:
#
# | Metric | Value |
# |:--|--:|
# | Customer Satisfaction | 92% |
# | Revenue Growth | 18% |
# | Net Profit Margin | 22% |
# | Employee Turnover Rate | 15% |
#
# Note: The sorted data is based on the numerical values in ascending order. The "Customer Satisfaction" metric has the highest value, followed by "Revenue Growth", "Net Profit Margin", and "Employee Turnover Rate".

# %% [markdown]
# ### 1.2. Parallel processing
# * Parallelization workflow for stakeholder impact analysis

# %%
# Example 2: Parallelization workflow for stakeholder impact analysis
# Process impact analysis for multiple stakeholder groups concurrently

stakeholders = [
    """Customers:
    - Price sensitive
    - Want better tech
    - Environmental concerns""",

    """Employees:
    - Job security worries
    - Need new skills
    - Want clear direction""",

    """Investors:
    - Expect growth
    - Want cost control
    - Risk concerns""",

    """Suppliers:
    - Capacity constraints
    - Price pressures
    - Tech transitions"""
]

impact_results = parallel(
    """Analyze how market changes will impact this stakeholder group.
    Provide specific impacts and recommended actions.
    Format with clear sections and priorities.""",
    stakeholders,
    n_workers = 1
)

for result in impact_results:
    print(result)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_http.py in hf_raise_for_status(response, endpoint_name)
#     405     try:
# --> 406         response.raise_for_status()
#     407     except HTTPError as e:
#
# /usr/local/lib/python3.10/dist-packages/requests/models.py in raise_for_status(self)
#    1023         if http_error_msg:
# -> 1024             raise HTTPError(http_error_msg, response=self)
#    1025
#
# HTTPError: 500 Server Error: Internal Server Error for url: https://api-inference.huggingface.co/models/Qwen/Qwen2.5-72B-Instruct
#
# The above exception was the direct cause of the following exception:
#
# HfHubHTTPError                            Traceback (most recent call last)
# <ipython-input-24-8c060e3f0482> in <cell line: 26>()
#      24 ]
#      25
# ---> 26 impact_results = parallel(
#      27     """Analyze how market changes will impact this stakeholder group.
#      28     Provide specific impacts and recommended actions.
#
# <ipython-input-22-257493bbfff8> in parallel(prompt, inputs, n_workers)
#       3     with ThreadPoolExecutor(max_workers=n_workers) as executor:
#       4         futures = [executor.submit(llm_call, f"{prompt}\nInput: {x}") for x in inputs]
# ----> 5         return [f.result() for f in futures]
#
# <ipython-input-22-257493bbfff8> in <listcomp>(.0)
#       3     with ThreadPoolExecutor(max_workers=n_workers) as executor:
#       4         futures = [executor.submit(llm_call, f"{prompt}\nInput: {x}") for x in inputs]
# ----> 5         return [f.result() for f in futures]
#
# /usr/lib/python3.10/concurrent/futures/_base.py in result(self, timeout)
#     456                     raise CancelledError()
#     457                 elif self._state == FINISHED:
# --> 458                     return self.__get_result()
#     459                 else:
#     460                     raise TimeoutError()
#
# /usr/lib/python3.10/concurrent/futures/_base.py in __get_result(self)
#     401         if self._exception:
#     402             try:
# --> 403                 raise self._exception
#     404             finally:
#     405                 # Break a reference cycle with the exception in self._exception
#
# /usr/lib/python3.10/concurrent/futures/thread.py in run(self)
#      56
#      57         try:
# ---> 58             result = self.fn(*self.args, **self.kwargs)
#      59         except BaseException as exc:
#      60             self.future.set_exception(exc)
#
# <ipython-input-12-faef48c89666> in llm_call(prompt, system_prompt, model)
#      16     client = InferenceClient()
#      17     input_prompt = system_prompt + '\n\n' + prompt
# ---> 18     response = client.text_generation(
#      19         input_prompt,
#      20         model=model,
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/inference/_client.py in text_generation(self, prompt, details, stream, model, adapter_id, best_of, decoder_input_details, do_sample, frequency_penalty, grammar, max_new_tokens, repetition_penalty, return_full_text, seed, stop, stop_sequences, temperature, top_k, top_n_tokens, top_p, truncate, typical_p, watermark)
#    2343                     watermark=watermark,
#    2344                 )
# -> 2345             raise_text_generation_error(e)
#    2346
#    2347         # Parse output
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/inference/_common.py in raise_text_generation_error(http_error)
#     464
#     465     # Otherwise, fallback to default error
# --> 466     raise http_error
#     467
#     468
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/inference/_client.py in text_generation(self, prompt, details, stream, model, adapter_id, best_of, decoder_input_details, do_sample, frequency_penalty, grammar, max_new_tokens, repetition_penalty, return_full_text, seed, stop, stop_sequences, temperature, top_k, top_n_tokens, top_p, truncate, typical_p, watermark)
#    2313         # Handle errors separately for more precise error messages
#    2314         try:
# -> 2315             bytes_output = self.post(json=payload, model=model, task="text-generation", stream=stream)  # type: ignore
#    2316         except HTTPError as e:
#    2317             match = MODEL_KWARGS_NOT_USED_REGEX.search(str(e))
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/inference/_client.py in post(self, json, data, model, task, stream)
#     304
#     305             try:
# --> 306                 hf_raise_for_status(response)
#     307                 return response.iter_lines() if stream else response.content
#     308             except HTTPError as error:
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_http.py in hf_raise_for_status(response, endpoint_name)
#     475         # Convert `HTTPError` into a `HfHubHTTPError` to display request information
#     476         # as well (request id and/or server error message)
# --> 477         raise _format(HfHubHTTPError, str(e), response) from e
#     478
#     479
#
# HfHubHTTPError: 500 Server Error: Internal Server Error for url: https://api-inference.huggingface.co/models/Qwen/Qwen2.5-72B-Instruct (Request ID: CD6MfUQneusF6myV4JHqP)
#
# Model too busy, unable to get response in less than 60 second(s)

# %% [markdown]
# ### 1.3. Routing
# * Route workflow for customer support ticket handling

# %%
# Example 3: Route workflow for customer support ticket handling
# Route support tickets to appropriate teams based on content analysis

support_routes = {
    "billing": """You are a billing support specialist. Follow these guidelines:
    1. Always start with "Billing Support Response:"
    2. First acknowledge the specific billing issue
    3. Explain any charges or discrepancies clearly
    4. List concrete next steps with timeline
    5. End with payment options if relevant

    Keep responses professional but friendly.

    Input: """,

    "technical": """You are a technical support engineer. Follow these guidelines:
    1. Always start with "Technical Support Response:"
    2. List exact steps to resolve the issue
    3. Include system requirements if relevant
    4. Provide workarounds for common problems
    5. End with escalation path if needed

    Use clear, numbered steps and technical details.

    Input: """,

    "account": """You are an account security specialist. Follow these guidelines:
    1. Always start with "Account Support Response:"
    2. Prioritize account security and verification
    3. Provide clear steps for account recovery/changes
    4. Include security tips and warnings
    5. Set clear expectations for resolution time

    Maintain a serious, security-focused tone.

    Input: """,

    "product": """You are a product specialist. Follow these guidelines:
    1. Always start with "Product Support Response:"
    2. Focus on feature education and best practices
    3. Include specific examples of usage
    4. Link to relevant documentation sections
    5. Suggest related features that might help

    Be educational and encouraging in tone.

    Input: """
}

# Test with different support tickets
tickets = [
    """Subject: Can't access my account
    Message: Hi, I've been trying to log in for the past hour but keep getting an 'invalid password' error.
    I'm sure I'm using the right password. Can you help me regain access? This is urgent as I need to
    submit a report by end of day.
    - John""",

    """Subject: Unexpected charge on my card
    Message: Hello, I just noticed a charge of $49.99 on my credit card from your company, but I thought
    I was on the $29.99 plan. Can you explain this charge and adjust it if it's a mistake?
    Thanks,
    Sarah""",

    """Subject: How to export data?
    Message: I need to export all my project data to Excel. I've looked through the docs but can't
    figure out how to do a bulk export. Is this possible? If so, could you walk me through the steps?
    Best regards,
    Mike"""
]

print("Processing support tickets...\n")
for i, ticket in enumerate(tickets, 1):
    print(f"\nTicket {i}:")
    print("-" * 40)
    print(ticket)
    print("\nResponse:")
    print("-" * 40)
    response = route(ticket, support_routes)
    print(response)
# Out:
# Processing support tickets...
#
#
# Ticket 1:
# ----------------------------------------
# Subject: Can't access my account
#     Message: Hi, I've been trying to log in for the past hour but keep getting an 'invalid password' error.
#     I'm sure I'm using the right password. Can you help me regain access? This is urgent as I need to
#     submit a report by end of day.
#     - John
#
# Response:
# ----------------------------------------
#
# Available routes: ['billing', 'technical', 'account', 'product']
# Routing Analysis:
#
# The user is experiencing difficulty logging into their account, which is a common issue related to account management and access. The urgency of the situation, as the user needs to submit a report by the end of the day, further emphasizes the need for prompt assistance. This type of issue is typically handled by the account support team, which can help reset passwords and resolve login issues.
#
#
# Selected route: account
#  Doe
#
# Account Support Response:
# Account Support Response: Hi John,
#
# Thank you for reaching out to us. We understand the urgency of your situation and will assist you in regaining access to your account as quickly as possible.
#
# To ensure the security of your account, we need to verify your identity. Please provide the following information:
# 1. The email address associated with your account.
# 2. The last four digits of the phone number linked to your account.
# 3. The approximate date you created your account.
#
# Once we have verified your identity, we can guide you through the steps to reset your password. Here’s what you can expect:
# 1. We will send you a verification code to the email address and phone number on file.
# 2. Follow the instructions to enter the verification code.
# 3. Create a new, strong password that includes a mix of uppercase and lowercase letters, numbers, and special characters.
#
# For security reasons, please do not share your password or verification codes with anyone, and avoid using the same password across multiple sites.
#
# We aim to resolve this issue within the next 30 minutes. If you have any further questions or concerns, please let us know.
#
# Best regards,
# Account Support Team
# ---
#
# Security Tips:
# - Always use a unique, strong password for each of your accounts.
# - Enable two-factor authentication (2FA) for an added layer of security.
# - Regularly update your passwords and security questions.
# - Be cautious of phishing attempts and only enter your credentials on official, secure websites.
#
# ---
#
# Please respond with the requested information so we can proceed with the verification process.
#
# Thank you,
# Account Support Team
# ---
#
# Note: If you do not receive a response from us within 30 minutes, please check your spam folder and add our email to your contacts to ensure you receive our communications.
#
# Best regards,
# Account Support Team
# ---
#
# We are committed to helping you regain access to your account and ensuring its security.
#
# Best regards,
# Account Support Team
# ---
#
# If you have any immediate concerns or need further assistance, please reply to this email or call our support line at [support phone number].
#
# Best regards,
# Account Support Team
# ---
#
# Thank you for your patience and cooperation.
#
# Best regards,
# Account Support Team
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
# ---
#
#
#
# Ticket 2:
# ----------------------------------------
# Subject: Unexpected charge on my card
#     Message: Hello, I just noticed a charge of $49.99 on my credit card from your company, but I thought
#     I was on the $29.99 plan. Can you explain this charge and adjust it if it's a mistake?
#     Thanks,
#     Sarah
#
# Response:
# ----------------------------------------
#
# Available routes: ['billing', 'technical', 'account', 'product']
# Routing Analysis:
#
#     The user is inquiring about an unexpected charge on their credit card, which is a financial matter. This indicates that the issue is related to billing and payments, and the user is seeking clarification and potentially a correction of the charge. The urgency level is moderate, as the user is concerned about the discrepancy in the amount charged.
#
#
# Selected route: billing
#
#
# Output:
# Billing Support Response: Hi Sarah,
#
# Thank you for reaching out to us. I understand you're seeing a $49.99 charge on your credit card and you believe you are on the $29.99 plan. I apologize for any confusion this may have caused.
#
# Let me explain the charge. It appears that your account was recently upgraded to our premium plan, which is $49.99 per month. This upgrade was likely due to the additional features and services you requested last month. However, if you did not authorize this upgrade, it was certainly a mistake on our end.
#
# To resolve this, I will need to verify your account details. Please provide your account number or the email address associated with your account. Once I have this information, I can review your account and, if necessary, adjust the charge and revert your plan back to the $29.99 plan.
#
# Here are the next steps:
# 1. Please reply to this email with your account number or email address.
# 2. I will review your account and confirm the details.
# 3. If the upgrade was unauthorized, I will issue a refund for the $20.00 difference and ensure your plan is set to the $29.99 plan.
# 4. I will provide you with a confirmation email once the changes are made, which should be within 24-48 hours.
#
# If you have any further questions or concerns, please don't hesitate to reach out. In the meantime, you can make a payment through our website or by calling our customer service line at 1-800-123-4567.
#
# Thank you for your patience and understanding.
#
# Best regards,
# [Your Name]
# Billing Support Specialist
# [Company Name]
#
# ---
#
# Please let me know if you need any further assistance or if there are any other issues you'd like to address.
#
# Best regards,
# [Your Name]
# Billing Support Specialist
# [Company Name]
# ---
#
# Thank you for your patience and understanding.
#
# Best regards,
# [Your Name]
# Billing Support Specialist
# [Company Name]
#
# ---
#
# Thank you for your patience and understanding.
#
# Best regards,
# [Your Name]
# Billing Support Specialist
# [Company Name]
# ---
#
# Thank you for your patience and understanding.
#
# Best regards,
# [Your Name]
# Billing Support Specialist
# [Company Name]
# ---
#
# Thank you for your patience and understanding.
#
# Best regards,
# [Your Name]
# Billing Support Specialist
# [Company Name]
# ---
#
# Thank you for your patience and understanding.
#
# Best regards,
# [Your Name]
# Billing Support Specialist
# [Company Name]
# ---
#
# Thank you for your patience and understanding.
#
# Best regards,
# [Your Name]
# Billing Support Specialist
# [Company Name]
# ---
#
# Thank you for your patience and understanding.
#
# Best regards,
# [Your Name]
# Billing Support Specialist
# [Company Name]
# ---
#
# Thank you for your patience and understanding.
#
# Best regards,
# [Your Name]
# Billing Support Specialist
# [Company Name]
# ---
#
# Thank you for your patience and understanding.
#
# Best regards,
# [Your Name]
# Billing Support Specialist
# [Company Name]
# ---
#
# Thank you for your patience and understanding.
#
# Best regards,
# [Your Name]
# Billing Support Specialist
# [Company Name]
# ---
#
# Thank you for your patience and understanding.
#
# Best regards,
# [Your Name]
# Billing Support Specialist
# [Company Name]
# ---
#
# Thank you for your patience and understanding.
#
# Best regards,
# [Your Name]
# Billing Support Specialist
# [Company Name]
# ---
#
# Thank you for your patience and understanding.
#
# Best regards,
# [Your Name]
# Billing Support Specialist
# [Company Name]
# ---
#
# Thank you for your patience and understanding.
#
# Best regards,
# [Your Name]
# Billing Support Specialist
# [Company Name]
# ---
#
# Thank you for your patience and understanding.
#
# Best regards,
# [Your Name]
# Billing Support Specialist
# [Company Name]
# ---
#
# Thank you for your patience and understanding.
#
# Best regards,
# [Your Name]
# Billing Support Specialist
# [Company Name]
# ---
#
# Thank you for your patience and understanding.
#
# Best regards,
# [Your Name]
# Billing Support Specialist
# [Company Name]
# ---
#
# Thank you for your patience and understanding.
#
# Best regards,
# [Your Name]
# Billing Support Specialist
# [Company Name]
# ---
#
# Thank you for your patience and understanding.
#
# Best regards,
# [Your Name]
# Billing Support Specialist
# [Company Name]
# ---
#
# Thank you for your patience and understanding.
#
# Best regards,
# [Your Name]
# Billing Support Specialist
# [Company Name]
# ---
#
# Thank you for your patience and understanding.
#
# Best regards,
# [Your Name]
# Billing Support Specialist
# [Company Name]
# ---
#
# Thank you for your patience and understanding.
#
# Best regards,
# [Your Name]
# Billing Support Specialist
# [Company Name]
# ---
#
# Thank you for your patience and understanding.
#
# Best regards,
# [Your Name]
# Billing Support Specialist
# [Company Name
#
# Ticket 3:
# ----------------------------------------
# Subject: How to export data?
#     Message: I need to export all my project data to Excel. I've looked through the docs but can't
#     figure out how to do a bulk export. Is this possible? If so, could you walk me through the steps?
#     Best regards,
#     Mike
#
# Response:
# ----------------------------------------
#
# Available routes: ['billing', 'technical', 'account', 'product']
# Routing Analysis:
#
# The user is requesting assistance with exporting project data to Excel, which involves the functionality and usage of the product. The message indicates that the user has already consulted the documentation but is still unable to perform the desired action. This suggests that the issue is related to the product's features and user interface, making it most appropriate to route this ticket to the product support team.
#
#
# Selected route: product
#
#
# Product Support Response:
# Certainly, Mike! Exporting your project data to Excel is a straightforward process, and I'm glad to guide you through it. This feature is particularly useful for detailed analysis or sharing data with team members who might not have access to our platform.
#
# ### Steps to Export Project Data to Excel:
#
# 1. **Navigate to the Project Overview:**
#    - Log in to your account and go to the project you want to export data from.
#    - Click on the project name to open the project overview page.
#
# 2. **Access the Data Export Section:**
#    - On the project overview page, look for the "Data" or "Data Management" tab. This is usually located in the top menu or sidebar.
#    - Click on the "Data" tab to access the data management section.
#
# 3. **Select the Data to Export:**
#    - In the data management section, you will see a list of all the data entries or datasets.
#    - Use the checkboxes to select the specific data entries you want to export. If you need to export all data, you can usually click a "Select All" button.
#
# 4. **Initiate the Export:**
#    - Once you have selected the data, look for an "Export" or "Download" button. This is typically located at the top of the data list or in the action menu.
#    - Click the "Export" button. You will be prompted to choose the export format. Select "Excel" from the options.
#
# 5. **Download the File:**
#    - After selecting the format, the system will prepare your file. This might take a few moments, depending on the size of the data.
#    - Once the file is ready, you will be prompted to download it. Save the file to your desired location on your computer.
#
# ### Additional Tips:
# - **Customize Your Export:**
#   - Before exporting, you can customize the data fields that are included in the export. This can be done by selecting or deselecting specific columns in the data management section.
#   - For example, if you only need certain metrics or attributes, you can uncheck the others to keep your Excel file more focused.
#
# - **Regular Backups:**
#   - Consider setting up regular data exports as part of your project management routine. This ensures you always have the latest data available for offline analysis or backups.
#
# ### Related Features:
# - **Data Filters:**
#   - If you need to export data based on specific criteria, you can use the data filters to narrow down your selection before exporting. This is especially useful for large datasets.
#   - For more information on using filters, check out our [Data Management Guide](https://example.com/data-management-guide).
#
# - **Automated Reports:**
#   - If you frequently need to share data with stakeholders, consider setting up automated reports. These can be scheduled to run at regular intervals and sent directly to your email or a shared drive.
#   - Learn more about automated reports in our [Reporting Section](https://example.com/reporting-section).
#
# I hope this helps, Mike! If you have any more questions or need further assistance, feel free to reach out. Happy exporting!
#
# Best regards,
# [Your Name]
# Product Support Team
#
# ---
#
# Feel free to let me know if you need any more details or if there's another feature you'd like to explore! 😊
# [Your Name]
# Product Support Team
# [Your Contact Information] 📧
# [Company Website] 🌐
# [Support Portal] 🔗
# [Community Forum] 🗣️
# [FAQs] ❓
# [Documentation] 📚
# [Feedback Form] 📝
# [Social Media Links] 📢
# [Privacy Policy] 🔒
# [Terms of Service] 📜
# [Unsubscribe] 🗑️
# [Company Address] 🏢
# [Company Phone Number] ☎️
# [Company Email] 📧
# [Company Logo] 📸
# [Company Tagline] 📢
# [Company Social Media Handles] 📢
# [Company Copyright] ©
# [Company Name] 🏢
# [Company Slogan] 📢
# [Company Mission Statement] 📢
# [Company Vision Statement] 📢
# [Company Core Values] 📢
# [Company History] 📢
# [Company Leadership Team] 📢
# [Company Careers Page] 📢
# [Company Press Releases] 📢
# [Company Blog] 📢
# [Company Customer Stories] 📢
# [Company Testimonials] 📢
# [Company Case Studies] 📢
# [Company Whitepapers] 📢
# [Company Webinars] 📢
# [Company Events] 📢
# [Company Partnerships] 📢
# [Company Customer Support] 📢
# [Company Community Guidelines

# %% [markdown]
# ## Orchestrator workers
# * In this workflow, a central LLM dynamically breaks down tasks, delegates them to worker LLMs, and synthesizes their results.

# %% [markdown]
# ## Evaluator optimizer
# * In this workflow, one LLM call generates a response while another provides evaluation and feedback in a loop.

# %%
evaluator_prompt = """
Evaluate this following code implementation for:
1. code correctness
2. time complexity
3. style and best practices

You should be evaluating only and not attemping to solve the task.
Only output "PASS" if all criteria are met and you have no further suggestions for improvements.
Output your evaluation concisely in the following format.

<evaluation>PASS, NEEDS_IMPROVEMENT, or FAIL</evaluation>
<feedback>
What needs improvement and why.
</feedback>
"""

generator_prompt = """
Your goal is to complete the task based on <user input>. If there are feedback
from your previous generations, you should reflect on them to improve your solution

Output your answer concisely in the following format:

<thoughts>
[Your understanding of the task and feedback and how you plan to improve]
</thoughts>

<response>
[Your code implementation here]
</response>
"""

task = """
<user input>
Implement a Stack with:
1. push(x)
2. pop()
3. getMin()
All operations should be O(1).
</user input>
"""

result, chain_of_thought = loop(task, evaluator_prompt, generator_prompt)
# Out:
# === INPUT START ===
# Full prompt:
#
# Your goal is to complete the task based on <user input>. If there are feedback
# from your previous generations, you should reflect on them to improve your solution
#
# Output your answer concisely in the following format:
#
# <thoughts>
# [Your understanding of the task and feedback and how you plan to improve]
# </thoughts>
#
# <response>
# [Your code implementation here]
# </response>
#
# Task:
# <user input>
# Implement a Stack with:
# 1. push(x)
# 2. pop()
# 3. getMin()
# All operations should be O(1).
# </user input>
#
#
#
# === INPUT END ===
#
# === GENERATION START ===
# Thoughts:
#
# I understand that the feedback is pointing out a flaw in my initial stack implementation, specifically with the getMin() operation. To improve, I need to ensure that the minimum element is tracked alongside the stack elements. This can be achieved by using an auxiliary stack that keeps track of the minimum elements.
#
# For the push operation, I will push the new element onto the main stack and then check if it is smaller than or equal to the current minimum. If it is, I will also push it onto the auxiliary stack. For the pop operation, I will remove the top element from the main stack and check if it is equal to the current minimum. If it is, I will also remove the top element from the auxiliary stack. The getMin operation will simply return the top element of the auxiliary stack.
#
# By maintaining an auxiliary stack for the minimum elements, I can ensure that all operations (push, pop, and getMin) have a time complexity of O(1).
#
#
# Generated:
#
# class MinStack:
#     def __init__(self):
#         self.stack = []
#         self.min_stack = []
#
#     def push(self, x):
#         self.stack.append(x)
#         if not self.min_stack or x <= self.min_stack[-1]:
#             self.min_stack.append(x)
#
#     def pop(self):
#         if self.stack:
#             top = self.stack.pop()
#             if top == self.min_stack[-1]:
#                 self.min_stack.pop()
#
#     def getMin(self):
#         if self.min_stack:
#             return self.min_stack[-1]
#         return None
#
# # Example usage:
# # stack = MinStack()
# # stack.push(5)
# # stack.push(3)
# # stack.push(7)
# # print(stack.getMin())  # Output: 3
# # stack.pop()
# # print(stack.getMin())  # Output: 3
#
# === GENERATION END ===
#
# === EVALUATION START ===
# Status: PASS
# Feedback:
# The code correctly implements a MinStack with O(1) time complexity for push, pop, and getMin operations. The use of two stacks, one to store all elements and another to keep track of the minimum element, is a common and efficient approach. The code follows good style and best practices, with clear method names, appropriate use of conditionals, and handling of edge cases (such as popping from an empty stack).
#
# However, there are a few minor improvements that could be made:
# 1. Add docstrings to the class and methods to provide better documentation and understanding of the code.
# 2. Consider adding input validation to ensure that the methods are called with valid arguments (e.g., checking for None values).
# 3. Use more descriptive variable names to improve code readability (e.g., `top` could be renamed to `popped_element`).
#
# These suggestions would enhance the code's maintainability and readability without affecting its correctness or performance.
#
# === EVALUATION END ===
